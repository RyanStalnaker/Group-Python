# %%
import pandas as pd
import numpy as np

# %%
data = "Resources/consumer_expenditures.csv"
data_df = pd.read_csv(data)
data_df.head()
# Out:
#     GeoFIPS        GeoName Region TableName  LineCode IndustryClassification  \
# 0   "00000"  United States           SAPCE1       1.0                    ...
# 1   "00000"  United States           SAPCE1       2.0                    ...
# 2   "00000"  United States           SAPCE1       3.0                    ...
# 3   "00000"  United States           SAPCE1       4.0                    ...
# 4   "00000"  United States           SAPCE1       5.0                    ...
#
#                                        Description  \
# 0               Personal consumption expenditures
# 1                                           Goods
# 2                                   Durable goods
# 3                        Motor vehicles and parts
# 4     Furnishings and durable household equipment
#
#                           Unit       1997       1998  ...        2012  \
# 0  Millions of current dollars  5536790.1  5877248.2  ...  11047363.2
# ...

# %%
data_df.count()
# Out:
# GeoFIPS                   1444
# GeoName                   1440
# Region                    1440
# TableName                 1440
# LineCode                  1440
# IndustryClassification    1440
# Description               1440
# Unit                      1440
# 1997                      1440
# 1998                      1440
# 1999                      1440
# 2000                      1440
# 2001                      1440
# 2002                      1440
# 2003                      1440
# 2004                      1440
# 2005                      1440
# 2006                      1440
# 2007                      1440
# 2008                      1440
# 2009                      1440
# 2010                      1440
# 2011                      1440
# 2012                      1440
# 2013                      1440
# 2014                      1440
# 2015                      1440
# 2016                      1440
# 2017                      1440
# 2018                      1440
# ...

# %%
data_df.dtypes
# Out:
# GeoFIPS                    object
# GeoName                    object
# Region                     object
# TableName                  object
# LineCode                  float64
# IndustryClassification     object
# Description                object
# Unit                       object
# 1997                      float64
# 1998                      float64
# 1999                      float64
# 2000                      float64
# 2001                      float64
# 2002                      float64
# 2003                      float64
# 2004                      float64
# 2005                      float64
# 2006                      float64
# 2007                      float64
# 2008                      float64
# 2009                      float64
# 2010                      float64
# 2011                      float64
# 2012                      float64
# 2013                      float64
# 2014                      float64
# 2015                      float64
# ...

# %%
data_df['GeoName'].value_counts()
# Out:
# United States           24
# Alabama                 24
# New Mexico              24
# New York                24
# North Carolina          24
# North Dakota            24
# Ohio                    24
# Oklahoma                24
# Oregon                  24
# Pennsylvania            24
# Rhode Island            24
# South Carolina          24
# South Dakota            24
# Tennessee               24
# Texas                   24
# Utah                    24
# Vermont                 24
# Virginia                24
# Washington              24
# West Virginia           24
# Wisconsin               24
# Wyoming                 24
# New England             24
# Mideast                 24
# Great Lakes             24
# Plains                  24
# Southeast               24
# Southwest               24
# Rocky Mountain          24
# New Jersey              24
# New Hampshire           24
# Nevada                  24
# Illinois                24
# Alaska                  24
# ...

# %%
df['Region'] = df['Employer'].replace(
    {'1': 'New England', '2': 'Mideast', '3': 'Great Lakes', '4': '', '5': '', '6': '', '7': '', '8': ''})
